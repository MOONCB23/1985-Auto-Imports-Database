# %%
import pandas as pd   
import numpy as np
pd.options.display.max_rows = 204
pd.options.display.max_columns = 204

# %%
df = pd.read_csv("auto.csv")

# %%
df.head(204)
# Out:
#              alfa-romero     gas    std   two  convertible  rwd  front   89  \
# 0            alfa-romero     gas    std   two  convertible  rwd  front   89
# 1     50            saab     gas    std   two    hatchback  fwd  front   99
# 2            alfa-romero     gas    std   two    hatchback  rwd  front   95
# 3      2       chevrolet     gas    std   two    hatchback  fwd  front   88
# 4     NaN          honda     gas    std  four        sedan  fwd  front   97
# 5     NaN          honda     gas    std   two    hatchback  fwd  front   94
# 6     NaN          honda     gas    std   two    hatchback  fwd  front   94
# 7     NaN          honda     gas    std   two    hatchback  fwd  front   94
# 8     37           honda     gas    std   two    hatchback  fwd  front   87
# 9     37           honda     gas    std   two    hatchback  fwd  front   87
# 10    78           honda     gas    std  four        wagon  fwd  front   97
# ...

# %%
headers = ["normalized-losses","make","fuel-type","aspiration","num-of-doors","body-style","drive-wheels","engine-location","wheel-base","length","width","height"
            "curb-weight","engine-type","num-of-cylinders","engine-size","fuel-system","bore","stroke","compression-ratio","horsepower","RPM","peak-rpm","city-mpg","highway-mpg","price"]

# %%
df.columns = headers

# %%
df.dtypes
# Out:
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base             int64
# length                 int64
# width                  int64
# heightcurb-weight      int64
# engine-type            int64
# num-of-cylinders      object
# engine-size           object
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio     object
# horsepower           float64
# RPM                   object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df.describe()
# Out:
#        wheel-base      length       width  heightcurb-weight  engine-type  \
# count  204.000000  204.000000  204.000000         204.000000   204.000000
# mean    68.269608   74.955882   66.009804          53.117647  1909.328431
# std     41.907603   20.963092    2.323557           7.240818  1129.967346
# min      0.000000    4.000000   60.000000           5.000000    28.000000
# 25%      8.000000   66.000000   64.000000          52.000000   876.000000
# 50%     95.000000   73.000000   66.000000          54.000000  2314.000000
# 75%     96.250000   84.250000   67.000000          56.000000  2739.500000
# max    100.000000  208.000000   77.000000          60.000000  4066.000000
#
#        horsepower    city-mpg  highway-mpg
# count  203.000000  204.000000   204.000000
# mean     9.142857   18.049020    28.784314
# std      3.820773   11.870299     9.777956
# min      0.000000    2.000000     3.000000
# 25%      9.000000    7.000000    24.000000
# ...

# %%
df.describe(include="all")
# Out:
#        normalized-losses    make fuel-type aspiration num-of-doors body-style  \
# count                199     204       204        204          204        204
# unique                43      22         2          2            3          5
# top                       toyota       gas        std         four      sedan
# freq                  40      32       184        167          114         96
# mean                 NaN     NaN       NaN        NaN          NaN        NaN
# std                  NaN     NaN       NaN        NaN          NaN        NaN
# min                  NaN     NaN       NaN        NaN          NaN        NaN
# 25%                  NaN     NaN       NaN        NaN          NaN        NaN
# 50%                  NaN     NaN       NaN        NaN          NaN        NaN
# 75%                  NaN     NaN       NaN        NaN          NaN        NaN
# max                  NaN     NaN       NaN        NaN          NaN        NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   normalized-losses  199 non-null    object
#  1   make               204 non-null    object
#  2   fuel-type          204 non-null    object
#  3   aspiration         204 non-null    object
#  4   num-of-doors       204 non-null    object
#  5   body-style         204 non-null    object
#  6   drive-wheels       204 non-null    object
#  7   engine-location    204 non-null    object
#  8   wheel-base         204 non-null    int64
#  9   length             204 non-null    int64
#  10  width              204 non-null    int64
#  11  heightcurb-weight  204 non-null    int64
#  12  engine-type        204 non-null    int64
#  13  num-of-cylinders   204 non-null    object
#  14  engine-size        204 non-null    object
#  15  fuel-system        204 non-null    object
# ...

# %%
df.dropna()
# Out:
#     normalized-losses           make fuel-type aspiration num-of-doors  \
# 0                        alfa-romero       gas        std          two
# 1                 50            saab       gas        std          two
# 2                        alfa-romero       gas        std          two
# 3                  2       chevrolet       gas        std          two
# 8                 37           honda       gas        std          two
# 9                 37           honda       gas        std          two
# 10                78           honda       gas        std         four
# 11                54        plymouth       gas        std         four
# 12                54        plymouth       gas        std         four
# 13                 8           dodge       gas        std          two
# 14                 8           dodge       gas        std          two
# 15                48           dodge       gas        std         four
# ...

# %%
df.dropna(subset=["price"], axis=0, inplace=True)

# %%
df['normalized-losses'] = pd.to_numeric(df['normalized-losses'], errors='coerce')

# %%
df.dtypes
# Out:
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base             int64
# length                 int64
# width                  int64
# heightcurb-weight      int64
# engine-type            int64
# num-of-cylinders      object
# engine-size           object
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio     object
# horsepower           float64
# RPM                   object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
mean = df["normalized-losses"].mean()

# %%
mean
# Out:
# 44.283018867924525

# %%
df["normalized-losses"].replace(np.nan, mean)
# Out:
# 0       44.283019
# 1       50.000000
# 2       44.283019
# 3        2.000000
# 4       44.283019
# 5       44.283019
# 6       44.283019
# 7       44.283019
# 8       37.000000
# 9       37.000000
# 10      78.000000
# 11      54.000000
# 12      54.000000
# 13       8.000000
# 14       8.000000
# 15      48.000000
# 16      48.000000
# 17      48.000000
# 18       6.000000
# 19       6.000000
# 20       6.000000
# 21       9.000000
# 22      54.000000
# 23      28.000000
# 24      22.000000
# 25      94.000000
# 26      94.000000
# 27      95.000000
# 28      44.283019
# 29       3.000000
# 30       4.000000
# 31       4.000000
# 32       4.000000
# 33       8.000000
# 34       8.000000
# 35      48.000000
# 36       6.000000
# 37       9.000000
# 38      98.000000
# 39      44.283019
# 40      44.283019
# 41      77.000000
# 42       8.000000
# 43       9.000000
# 44      87.000000
# 45      87.000000
# 46      74.000000
# 47       3.000000
# 48      68.000000
# 49      68.000000
# ...

# %%
df ["highway-mpg"] = 235/ df ["highway-mpg"]

# %%
df.rename(columns = {"highway-mpg" : "city-L/100km"} , inplace =True)

# %%
df.head(10)
# Out:
#    normalized-losses         make fuel-type aspiration num-of-doors  \
# 0                NaN  alfa-romero       gas        std          two
# 1               50.0         saab       gas        std          two
# 2                NaN  alfa-romero       gas        std          two
# 3                2.0    chevrolet       gas        std          two
# 4                NaN        honda       gas        std         four
# 5                NaN        honda       gas        std          two
# 6                NaN        honda       gas        std          two
# 7                NaN        honda       gas        std          two
# 8               37.0        honda       gas        std          two
# 9               37.0        honda       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front          89      69     64
# 1    hatchback          fwd           front          99      87     67
# ...

# %%
df["length"] = df["length"]/df["length"].max()

# %%
df["length"].head(10)
# Out:
# 0    0.331731
# 1    0.418269
# 2    0.033654
# 3    0.019231
# 4    0.302885
# 5    0.240385
# 6    0.240385
# 7    0.240385
# 8    0.216346
# 9    0.216346
# Name: length, dtype: float64

# %%
df ["length"] = ( df ["length"] - df["length"].min() ) / ( df ["length"].max() - df["length"].min() )

# %%
df["length"].head(10)
# Out:
# 0    0.318627
# 1    0.406863
# 2    0.014706
# 3    0.000000
# 4    0.289216
# 5    0.225490
# 6    0.225490
# 7    0.225490
# 8    0.200980
# 9    0.200980
# Name: length, dtype: float64

# %%
df ["length"] = ( df ["length"] - df["length"].mean() ) / df ["length"].std()

# %%
df["length"].head(10)
# Out:
# 0   -0.284113
# 1    0.574539
# 2   -3.241692
# 3   -3.384800
# 4   -0.570330
# 5   -1.190468
# 6   -1.190468
# 7   -1.190468
# 8   -1.428982
# 9   -1.428982
# Name: length, dtype: float64
